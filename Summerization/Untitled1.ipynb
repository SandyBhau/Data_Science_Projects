# %%
 
import requests 
from bs4 import BeautifulSoup

# %%
query = "Weather"

# %%
url = f"https://www.google.com/search?q={query}"
response = requests.get(url, verify=False) 
# print(response.content)

# %%
soup = BeautifulSoup(response.text, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head><style nonce="xzA8gHkjewnes5uGWlQuRg">
# a, a:link, a:visited, a:active, a:hover {
#   color: #1a73e8;
#   text-decoration: none;
# }
# body {
#   font-family: Roboto,Helvetica,Arial,sans-serif;
#   text-align: center;
#   -ms-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   -webkit-text-size-adjust: 100%;
# }
# .box {
#   border: 1px solid #dadce0;
#   box-sizing: border-box;
#   border-radius: 8px;
#   margin: 24px auto 5px auto;
#   max-width: 800px;
#   padding: 24px;
# }
# .youtubeContainerUIModernization,
# .boxUIModernization {
#   box-sizing: border-box;
#   margin-left: auto;
#   margin-right: auto;
#   max-width: 800px;
# }
# .signInContainerUIModernization {
#     display: flex;
#     justify-content: flex-end;
# }
# h1 {
#   color: #2c2c2c;
#   font-size: 24px;
#   hyphens: auto;
#   margin: 24px 0;
# }
# .icaCallout {
#   background-color: #f8f9fa;
#   padding: 12px 16px;
#   border-radius: 10px;
# ...

# %%
soup.find_all("a")
# Out:
# [<a class="basebutton hairlinebutton hideOnSmallWidth" href="https://accounts.google.com/ServiceLogin?hl=en&amp;continue=https://www.google.com/search?q%3DWeather&amp;gae=cb-none">Sign in</a>,
#  <a class="basebutton hairlinebutton hideOnNormalWidth" href="https://accounts.google.com/ServiceLogin?hl=en&amp;continue=https://www.google.com/search?q%3DWeather&amp;gae=cb-none">Sign in</a>,
#  <a href="https://policies.google.com/technologies/cookies?hl=en&amp;utm_source=ucb" target="_blank">cookies</a>,
#  <a class="basebutton nolinebutton" href="https://consent.google.com/dl?continue=https://www.google.com/search?q%3DWeather&amp;gl=GB&amp;hl=en&amp;cm=2&amp;pc=srp&amp;uxe=none&amp;src=1">More options</a>,
#  <a href="https://policies.google.com/privacy?hl=en&amp;utm_source=ucb">Privacy Policy</a>,
#  <a href="https://policies.google.com/terms?hl=en&amp;utm_source=ucb">Terms of Service</a>]

# %%
# Find all search result links
# search_results = soup.find_all("div", class_="header-main__container")
search_results = soup.find_all("a")
search_results
# Out:
# []

# %%
results1 = []

# %%
for result in search_results:
    link = result.find("a")["href"]
    print(link)
#     name = result.find("h3").get_text()
#     description = result.find("span").get_text()
#     print(description)
#     results1.append({"link": link, "description": description})

# %%
search_results
# Out:
# [<a class="basebutton hairlinebutton hideOnSmallWidth" href="https://accounts.google.com/ServiceLogin?hl=en&amp;continue=https://www.google.com/search?q%3DWeather&amp;gae=cb-none">Sign in</a>,
#  <a class="basebutton hairlinebutton hideOnNormalWidth" href="https://accounts.google.com/ServiceLogin?hl=en&amp;continue=https://www.google.com/search?q%3DWeather&amp;gae=cb-none">Sign in</a>,
#  <a href="https://policies.google.com/technologies/cookies?hl=en&amp;utm_source=ucb" target="_blank">cookies</a>,
#  <a class="basebutton nolinebutton" href="https://consent.google.com/dl?continue=https://www.google.com/search?q%3DWeather&amp;gl=GB&amp;hl=en&amp;cm=2&amp;pc=srp&amp;uxe=none&amp;src=1">More options</a>,
#  <a href="https://policies.google.com/privacy?hl=en&amp;utm_source=ucb">Privacy Policy</a>,
#  <a href="https://policies.google.com/terms?hl=en&amp;utm_source=ucb">Terms of Service</a>]

# %%
query = "weather"
url = f"https://www.google.com/search?q={query}"
response = requests.get(url, verify=False) 
soup = BeautifulSoup(response.content, "html.parser")
search_results = soup.find_all("a")
link_list = []
for result in search_results:
    link = result.get('href')
    link_list.append(link)
    print(link)
    print(result.get_text())
# Out:
# https://accounts.google.com/ServiceLogin?hl=en&continue=https://www.google.com/search?q%3Dweather&gae=cb-none
# Sign in
# https://accounts.google.com/ServiceLogin?hl=en&continue=https://www.google.com/search?q%3Dweather&gae=cb-none
# Sign in
# https://policies.google.com/technologies/cookies?hl=en&utm_source=ucb
# cookies
# https://consent.google.com/dl?continue=https://www.google.com/search?q%3Dweather&gl=GB&hl=en&cm=2&pc=srp&uxe=none&src=1
# More options
# https://policies.google.com/privacy?hl=en&utm_source=ucb
# Privacy Policy
# https://policies.google.com/terms?hl=en&utm_source=ucb
# Terms of Service

# %%
query = "Data Science"
url = f"https://www.google.com/search?q={query}"
response = requests.get(url, verify=False) 
soup = BeautifulSoup(response.text, "html.parser")
search_results = soup.find_all("div")
link_list = []
for result in search_results:
    link = result.get('href')
    link_list.append(link) 
    print(link)
#     break
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
query = "Data Science"
url = f"https://en.wikipedia.org/wiki/{query}"
response = requests.get(url, verify=False) 
soup = BeautifulSoup(response.content, "html.parser")
search_results= soup.find_all('div', class_="mw-body-content")
for result in search_results:
    print(result.get_text())
    break
# Out:
# C:\Users\Sandesh.Bharitkar\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'en.wikipedia.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\Sandesh.Bharitkar\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'en.wikipedia.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Interdisciplinary field of study on deriving knowledge and insights from data
# Not to be confused with information science.
#
#
# The existence of Comet NEOWISE (here depicted as a series of red dots) was discovered by analyzing astronomical survey data acquired by a space telescope, the Wide-field Infrared Survey Explorer.
# ...

# %%
search_results= soup.find_all('div', class_="hatnote navigation-not-searchable")
search_results
# Out:
# [<div class="hatnote navigation-not-searchable" role="note">This article is about the atmospheric process. For the geological process, see <a href="/wiki/Weathering" title="Weathering">Weathering</a>. For other uses, see <a class="mw-disambig" href="/wiki/Weather_(disambiguation)" title="Weather (disambiguation)">Weather (disambiguation)</a> and <a class="mw-disambig" href="/wiki/Weather_systems_(disambiguation)" title="Weather systems (disambiguation)">Weather systems (disambiguation)</a>.</div>,
#  <div class="hatnote navigation-not-searchable" role="note">"Fair weather" redirects here. For other uses, see <a class="mw-redirect mw-disambig" href="/wiki/Fairweather_(disambiguation)" title="Fairweather (disambiguation)">Fairweather (disambiguation)</a>.</div>,
#  <div class="hatnote navigation-not-searchable" role="note">Main article: <a href="/wiki/Weathering" title="Weathering">Weathering</a></div>,
# ...

# %%
for result in search_results:
    print(result.get_text())
# Out:
# This article is about the atmospheric process. For the geological process, see Weathering. For other uses, see Weather (disambiguation) and Weather systems (disambiguation).
# "Fair weather" redirects here. For other uses, see Fairweather (disambiguation).
# Main article: Weathering
# Further information: Biometeorology
# Main article: Weather forecasting
# Main articles: Extremes on Earth and List of weather records
# Main article: Space weather

# %%
print('Classes of each table:')
for div in soup.find_all('div'):
    print(div.get('class'))
# Out:
# Classes of each table:
# ['vector-header-container']
# ['vector-header-start']
# ['vector-dropdown', 'vector-main-menu-dropdown', 'vector-button-flush-left', 'vector-button-flush-right']
# ['vector-dropdown-content']
# ['vector-unpinned-container']
# ['vector-main-menu', 'vector-pinnable-element']
# ['vector-pinnable-header', 'vector-main-menu-pinnable-header', 'vector-pinnable-header-unpinned']
# ['vector-pinnable-header-label']
# ['vector-menu', 'mw-portlet', 'mw-portlet-navigation']
# ['vector-menu-heading']
# ['vector-menu-content']
# ['vector-menu', 'mw-portlet', 'mw-portlet-interaction']
# ['vector-menu-heading']
# ['vector-menu-content']
# ['vector-main-menu-action', 'vector-main-menu-action-lang-alert']
# ['vector-main-menu-action-item']
# ['vector-main-menu-action-heading', 'vector-menu-heading']
# ['vector-main-menu-action-content', 'vector-menu-content']
# ...

# %%
# Creating list with all tables
tables = soup.find_all('table')

#  Looking for the table with the classes 'wikitable' and 'sortable'
table = soup.find('table', class_='wikitable sortable')

# %%
table

# %%
soup.title.get_text()
# Out:
# 'Weather - Wikipedia'

# %%
url
# Out:
# 'https://www.google.com/search?q=Weather'

# %%
response.content
# Out:
# b'<!DOCTYPE html><html lang="en" dir="ltr"><head><style nonce="7fkR3bXAkC52hYXFSsBXjg">\na, a:link, a:visited, a:active, a:hover {\n  color: #1a73e8;\n  text-decoration: none;\n}\nbody {\n  font-family: Roboto,Helvetica,Arial,sans-serif;\n  text-align: center;\n  -ms-text-size-adjust: 100%;\n  -moz-text-size-adjust: 100%;\n  -webkit-text-size-adjust: 100%;\n}\n.box {\n  border: 1px solid #dadce0;\n  box-sizing: border-box;\n  border-radius: 8px;\n  margin: 24px auto 5px auto;\n  max-width: 800px;\n  padding: 24px;\n}\n.youtubeContainerUIModernization,\n.boxUIModernization {\n  box-sizing: border-box;\n  margin-left: auto;\n  margin-right: auto;\n  max-width: 800px;\n}\n.signInContainerUIModernization {\n    display: flex;\n    justify-content: flex-end;\n}\nh1 {\n  color: #2c2c2c;\n  font-size: 24px;\n  hyphens: auto;\n  margin: 24px 0;\n}\n.icaCallout {\n  background-color: #f8f9fa;\n  padding: 12px 16px;\n  border-radius: 10px;\n  margin-bottom: 10px;\n}\n.icaCalloutUIModernization
# ...

# %%
result.get_text()
# Out:
# 'Terms of Service'
