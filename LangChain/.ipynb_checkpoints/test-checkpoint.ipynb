# %%
print("Hello")
# Out:
# Hello

# %%
import os
from dotenv import load_dotenv, find_dotenv
from pinecone import Pinecone

# %%
load_dotenv(find_dotenv(),override = True)
# Out:
# True

# %%
print(os.getenv('PINECONE_API_KEY'))
# Out:
# 1db6db05-1f45-4947-bc0e-b0b95747b7cd

# %%
pc = Pinecone(
    api_key = 'ab0c15e0-3e29-4101-b318-9dc814815664'
)

# %%
pc.list_indexes()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\Sandesh.Bharitkar\OneDrive - EY\Desktop\Sandesh\Learning\Data Science\Jupyter+Notebok+Files\LangChain\venv\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\Sandesh.Bharitkar\OneDrive - EY\Desktop\Sandesh\Learning\Data Science\Jupyter+Notebok+Files\LangChain\venv\lib\site-packages\urllib3\connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...

# %%
pc.list_indexes()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\Sandesh.Bharitkar\OneDrive - EY\Desktop\Sandesh\Learning\Data Science\Jupyter+Notebok+Files\LangChain\venv\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\Sandesh.Bharitkar\OneDrive - EY\Desktop\Sandesh\Learning\Data Science\Jupyter+Notebok+Files\LangChain\venv\lib\site-packages\urllib3\connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...
